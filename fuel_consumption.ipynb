# %% [markdown]
# Some info on the dataset:
#
# The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).
#
# [, 0]	 Model
#
# [, 1]	mpg	Miles/(US) gallon
#
# [, 2]	cyl	Number of cylinders
#
# [, 3]	disp	Displacement (cu.in.)
#
# [, 4]	hp	Gross horsepower
#
# [, 5]	drat	Rear axle ratio
#
# [, 6]	wt	Weight (1000 lbs)
#
# [, 7]	qsec	1/4 mile time
#
# [, 8]	vs	Engine (0 = V-shaped, 1 = straight)
#
# [, 9]	am	Transmission (0 = automatic, 1 = manual)
#
# [,10]	gear	Number of forward gears
#
# [,11]	carb	Number of carburetors

# %%
# Solve Here
import pandas as pd
df = pd.read_csv("C:/Users/HP/Downloads/mpg_data.csv") # Loading Dataset
first_five = df.head(5)
last_two = df.tail(2)
print("The first five rows of the data are\n",first_five)
print("The last two rows of the data are\n",last_two)
# Out:
# The first five rows of the data are
#                 model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# The last two rows of the data are
#              model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8
# 31     Volvo 142E  21.4    4  121.0  109  4.11  2.78  18.6   1   1     4     2

# %% [markdown]
# Calculate the mean and the variance for each of the columns

# %%
# Solve Here
import numpy as np
mean = df.mean(numeric_only=True)       # Calculating Mean and Variance
variance =df.var(numeric_only=True)
print("The mean of each column in the data are \n",mean)
print("The Variance of each column in the data are \n",variance)
# Out:
# The mean of each column in the data are
#  mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64
# The Variance of each column in the data are
#  mpg        36.324103
# cyl         3.189516
# disp    15360.799829
# hp       4700.866935
# drat        0.285881
# wt          0.957379
# qsec        3.193166
# vs          0.254032
# am          0.248992
# gear        0.544355
# carb        2.608871
# dtype: float64

# %% [markdown]
# The first column is called model. Although being called model, it contains the make and the model of the car. I would like you to find the average for all the columns grouped by the car make. Hint, the car make is the first word in the model column

# %%
# Solve Here
df['carmake'] = df['model'].str.split(n=1).str[0]     #String Manipulation
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
average_bymake = df.groupby('carmake').mean(numeric_only=2)
average_bymake
# Out:
#                 mpg       cyl        disp          hp      drat        wt  \
# carmake
# AMC       15.200000  8.000000  304.000000  150.000000  3.150000  3.435000
# Cadillac  10.400000  8.000000  472.000000  205.000000  2.930000  5.250000
# Camaro    13.300000  8.000000  350.000000  245.000000  3.730000  3.840000
# Chrysler  14.700000  8.000000  440.000000  230.000000  3.230000  5.345000
# Datsun    22.800000  4.000000  108.000000   93.000000  3.850000  2.320000
# Dodge     15.500000  8.000000  318.000000  150.000000  2.760000  3.520000
# Duster    14.300000  8.000000  360.000000  245.000000  3.210000  3.570000
# Ferrari   19.700000  6.000000  145.000000  175.000000  3.620000  2.770000
# Fiat      29.850000  4.000000   78.850000   66.000000  4.080000  2.067500
# Ford      15.800000  8.000000  351.000000  264.000000  4.220000  3.170000
# Honda     30.400000  4.000000   75.700000   52.000000  4.930000  1.615000
# ...

# %% [markdown]
# Check if there is any duplications and nan in the dataset

# %%
# Solve Here
duplicates = df[df.duplicated()]    # Checking duplicates
print(duplicates)

#checking for NaN values
nan_count = df.isnull().sum()        # Checking Nan's
print(nan_count)
# Out:
# Empty DataFrame
# Columns: [model, mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb, carmake]
# Index: []
# model      0
# mpg        0
# cyl        0
# disp       0
# hp         0
# drat       0
# wt         0
# qsec       0
# vs         0
# am         0
# gear       0
# carb       0
# carmake    0
# dtype: int64

# %% [markdown]
# ## 2- Linear Regression
# In this section we will do linear regression on the data given to us. First, we start by showing some plots

# %% [markdown]
# refresh how we can do scatter plots in python. Now do a scatter plot for mpg and disp where mpg is on the y axis and disp is the x axis. Do you see strong relationship between them? explain

# %%
import matplotlib.pyplot as plt
plt.scatter(df.disp,df.mpg)

# %%
# Solve and Comment Here
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6)) #Setting the fighure size
plt.scatter(df.disp, df.mpg,marker='.', color='b') 
plt.title('Scatter plot of mpg and disp')  #setting the title
plt.xlabel('disp')    #setting the label for x axis  
plt.ylabel('mpg')       #setting the label for y axis 
plt.grid(True)      #adding a grid
plt.show()         #displaying the plot

# %% [markdown]
# Build your own linear regression as we did in the lecture to calculate the coefficients and intercept that minimizes the lease square error when predicting mpg using disp. Use the following training parameter values for initial weight and bias -0.1, 30. And for learning rate 0.00001 and 100 for the number of iterations. What are the values for the coefficients and intercept

# %%
# Solve Here
def predict_MPG(feature, weights, bias):
   prediction = weights*feature + bias
   return prediction

# %%
w1,b1 = [-0.1, 30]
y1 = predict_MPG(df.disp, w1, b1)

# %%
def cost_function(true, predicted):
    error = sum((true - predicted)**2)/len(true)
    return error

# %%
print(cost_function(df.disp,y1))
# Out:
# 68089.51995937499

# %%
def update_weights(features, true, weights, bias, learning_rate):
    deriv_w = -2/len(true)*sum(features*(true-(weights*features+bias)))
    deriv_b = -2/len(true)*sum((true-(weights*features+bias)))
    weights = weights - learning_rate*deriv_w
    bias = bias - learning_rate*deriv_b
    return weights, bias

# %%
def train(features, true, weight, bias, learning_rate,iters):
    cost_history=[]
    for i in range(iters):
        predictions=predict_MPG(features,weight,bias)
        cost = cost_function(true, predictions)
        cost_history.append(cost)
        weight , bias = update_weights(features, true, weight, bias, learning_rate)
    return weight , bias, cost_history

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
w,b, c = train(df.disp, df.mpg, -0.1, 30., 0.00001,1000)
print(w,b)
print(c)
# Out:
# -0.04256529170998576 29.998449112245602
# ...

# %% [markdown]
# Check if you get the same using sklearn linear regression model

# %%
from sklearn.model_selection import train_test_split
x = df[['disp']]
x_train,x_test, y_train, y_test = train_test_split(x,df.mpg,test_size=0.01, random_state=123)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(x_train)
x_train_scaled = scaler.transform(x_train)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x_train,y_train)

# %%
print('coeffs are ', model.coef_)
print('bias is ', model.intercept_)
# Out:
# coeffs are  [-0.04105856]
# bias is  29.536005318949

# %% [markdown]
# Make a variable  called my_own_disp that goes between 100 and 500 with a step of 1. Use the variable and the coefficients calculated from the linear regression model to calculate the pred of mpg at each value of my_own_disp. Remember the equation pred=w0+w1*x. Plot the resulted line along with the scatter plot you plotted earlier and see if that is a good fit

# %%
# Solve Here
my_own_disp = pd.DataFrame(range(100,500,1))
pred_mpg = predict_MPG(my_own_disp,w,b)
pred_mpg
# Out:
#              0
# 0    25.742958
# 1    25.700388
# 2    25.657817
# 3    25.615247
# 4    25.572676
# ..         ...
# 395   8.927567
# 396   8.884996
# 397   8.842426
# 398   8.799855
# 399   8.757284
#
# [400 rows x 1 columns]

# %%
# Solve and Comment Here
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6)) #Setting the fighure size
plt.scatter(df.disp, df.mpg,marker='.', color='b') 
plt.plot(my_own_disp, pred_mpg, color='r', label='Predicted Line')
plt.title('Scatter plot of mpg and disp')  #setting the title
plt.xlabel('disp')    #setting the label for x axis  
plt.ylabel('mpg')       #setting the label for y axis 
plt.grid(True)      #adding a grid
plt.show()         #displaying the plot

# %% [markdown]
# Do a scatter plot between mpg and each of the features other than the model. Can you visually tell which features are more important in calculating the mpg?

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
# Solve Here

plt.scatter(df.mpg,df.cyl)

# %%
plt.scatter(df.mpg,df.disp)

# %%
plt.scatter(df.mpg,df.hp)

# %%
plt.scatter(df.mpg,df.drat)

# %%
plt.scatter(df.mpg,df.wt)

# %%
plt.scatter(df.mpg,df.qsec)

# %%
plt.scatter(df.mpg,df.vs)

# %%
plt.scatter(df.mpg,df.am)

# %%
plt.scatter(df.mpg,df.gear)

# %%
plt.scatter(df.mpg,df.carb)

# %% [markdown]
# ### Ans: After seeing the plots visually, I think disp,hp,drat,wt would be important features

# %% [markdown]
# Now, do a linear regression model using sklearn to fit all the features except the model and predict the mpg. What are the coefficients for each feature? Based on the coefficients, can you tell which features are important? Does it match your expectations from what you have visually seen?

# %%
# Solve and Comment Here
from sklearn.model_selection import train_test_split
X = df[['disp','cyl','hp','drat','wt','qsec','vs','am','gear','carb']]
X_train,X_test, Y_train, Y_test = train_test_split(X,df.mpg,test_size=0.01, random_state=123)

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression().fit(X_train,Y_train)

# %%
print('coeffs are ', model1.coef_)
print('bias is ', model1.intercept_)
# Based on the Coefficients I can tell wt,am are strong features because higher the coefficient it has strong impact on mpg(EWxcluding Categorical Variables)
#After seeing the graphs, Some features matched my expectations like disp,hp,drat,wt because the graphs seemed linear.
# Out:
# coeffs are  [ 0.01223879  0.14224313 -0.01765593  0.93008236 -3.87193642  0.95600215
#   0.35086448  3.28824994  0.32526924 -0.23080916]
# bias is  8.89661750413261
